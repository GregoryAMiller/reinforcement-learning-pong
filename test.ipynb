# %%
import gym
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (8, 8), strides=(4, 4), activation='relu', input_shape=(210, 160, 3)),
    tf.keras.layers.Conv2D(64, (4, 4), strides=(2, 2), activation='relu'),
    tf.keras.layers.Conv2D(64, (3, 3), strides=(1, 1), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # Only two actions: 2 and 3
])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

def compute_loss(probabilities, actions, rewards):
    """
    Computes the loss for policy gradient methods.
    
    Args:
        probabilities: Tensor of shape (batch_size, num_actions). 
                       The probability of taking each action in each state.
        actions: Tensor of shape (batch_size,). The actions taken.
        rewards: Tensor of shape (batch_size,). The rewards obtained.
        
    Returns:
        loss: A scalar Tensor representing the loss.
    """
    # Ensure the tensors are of correct data type and shape
    actions = tf.cast(actions, tf.int32)
    rewards = tf.cast(rewards, tf.float32)
    
    # Compute the return G_t
    # Note: You might want to compute a discounted return
    # G_t = r_t + gamma * r_{t+1} + gamma^2 * r_{t+2} + ... 
    # where gamma is a discount factor in [0, 1]
    
    # For simplicity, let's consider G_t = r_t for this example
    G_t = rewards
    
    # Compute the log probabilities of the actions taken
    indices = tf.range(0, tf.shape(probabilities)[0]) * tf.shape(probabilities)[1] + actions
    chosen_probabilities = tf.gather(tf.reshape(probabilities, [-1]), indices)
    log_probabilities = tf.math.log(chosen_probabilities)
    
    # Compute the loss
    loss = -tf.reduce_mean(log_probabilities * G_t)
    
    return loss

# %%
# Function to render environment and optionally display using matplotlib
def render(env, mode='human'):
    if mode == 'human':
        env.render()
    elif mode == 'rgb_array':
        img = env.render(mode='rgb_array')
        plt.imshow(img)
        plt.axis('off')
        plt.show()

# %%
# Define the environment
env = gym.make("ALE/Pong-v5", render_mode="human")

# %%
num_episodes = 1000

for episode in range(num_episodes):
    state = env.reset()
    # print(state)
    # Extract image data if state is a tuple
    actual_state = state[0] if isinstance(state, tuple) else state
    done = False
    
    states, actions, rewards, probs = [], [], [], []
    
    with tf.GradientTape() as tape:
        for t in range(1000):  # Limiting to 1000 timesteps per episode
            # if episode % 100 == 0:  # Render every 100 episodes
            render(env, mode='human')  
            # env.render()
            # Convert state to suitable input for network
            # Convert state to suitable input for network WITHOUT flattening
            state_input = tf.convert_to_tensor([actual_state], dtype=tf.float32) 
            
            # Predict action probabilities and choose action
            action_prob = model(state_input)
            # print(action_prob)
            initial_epsilon = 1.0
            final_epsilon = 0.01
            decay_rate = 0.995
            epsilon = initial_epsilon * (decay_rate ** episode)

            if np.random.rand() < epsilon:
                action = np.random.choice([2, 3])
            else:
                action_prob = model(state_input)
                action = np.random.choice([2, 3], p=np.squeeze(action_prob.numpy()))
            # print(action)
            # Take step in environment
            next_state, reward, done, info, additional_value = env.step(action)
            


            # print(state)
            # print(action)
            # if action == 2 or action == 3:  # if the paddle moves up or down
            #     reward += 0.05
            # if action != 2 and action != 3:  # if the paddle doesn't move
            #     reward -= 1
            # Amplify reward if the ball is hit
            if reward == 1:  # If the agent scores a point
                reward += 10  # Add an additional reward
            if reward == -1:  # If the agent misses the ball
                reward -= 2  # Penalize more heavily
            # Check if the ball was hit
            # if reward == 0:
            #     reward += 1
            
            
            # Store state, action, reward
            states.append(state)
            actions.append(action)
            rewards.append(reward)
            probs.append(action_prob)
            
            state = next_state
            
            print(f"Episode: {episode}, Reward: {reward}, Total Reward: {np.sum(rewards)}")
            if done:
                break
        
        # Compute loss value
        print(f'Computing Loss')
        loss_value = compute_loss(probs, actions, rewards)
        print(f'loss_value: {loss_value}')
    # Compute gradient and perform optimization
    print('calulating gradient')
    grads = tape.gradient(loss_value, model.trainable_variables)
    print('gradient done')
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    print('optimizer done')
    # Optionally, log metrics like episode reward, loss etc.
    
    if episode % 10 == 0:
        print(f"END: Episode: {episode}, Total Reward: {np.sum(rewards)}")

# Close the environment
print('Closing environment')
env.close()
# Out:
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: 0.0, Total Reward: 0.0
# Episode: 0, Reward: -3.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: 0.0, Total Reward: -3.0
# Episode: 0, Reward: -3.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: 0.0, Total Reward: -6.0
# Episode: 0, Reward: -3.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: 0.0, Total Reward: -9.0
# Episode: 0, Reward: -3.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: 0.0, Total Reward: -12.0
# Episode: 0, Reward: -3.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: 0.0, Total Reward: -15.0
# Episode: 0, Reward: -3.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: 0.0, Total Reward: -18.0
# Episode: 0, Reward: -3.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: 0.0, Total Reward: -21.0
# Episode: 0, Reward: -3.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: 0.0, Total Reward: -24.0
# Episode: 0, Reward: -3.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: 0.0, Total Reward: -27.0
# Episode: 0, Reward: -3.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: 0.0, Total Reward: -30.0
# Episode: 0, Reward: -3.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: 0.0, Total Reward: -33.0
# Episode: 0, Reward: -3.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: 0.0, Total Reward: -36.0
# Episode: 0, Reward: -3.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: 0.0, Total Reward: -39.0
# Episode: 0, Reward: -3.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: 0.0, Total Reward: -42.0
# Episode: 0, Reward: -3.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: 0.0, Total Reward: -45.0
# Episode: 0, Reward: -3.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: 0.0, Total Reward: -48.0
# Episode: 0, Reward: -3.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: 0.0, Total Reward: -51.0
# Episode: 0, Reward: -3.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: 0.0, Total Reward: -54.0
# Episode: 0, Reward: -3.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: 0.0, Total Reward: -57.0
# Episode: 0, Reward: -3.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: 0.0, Total Reward: -60.0
# Episode: 0, Reward: -3.0, Total Reward: -63.0
# Computing Loss
# loss_value: -0.2385178506374359
# calulating gradient
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# c:\Users\Grego\Desktop\reinforcement learning pong\test.ipynb Cell 6 line <cell line: 3>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Grego/Desktop/reinforcement%20learning%20pong/test.ipynb#W5sZmlsZQ%3D%3D?line=71'>72</a> # Compute gradient and perform optimization
#      <a href='vscode-notebook-cell:/c%3A/Users/Grego/Desktop/reinforcement%20learning%20pong/test.ipynb#W5sZmlsZQ%3D%3D?line=72'>73</a> print('calulating gradient')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Grego/Desktop/reinforcement%20learning%20pong/test.ipynb#W5sZmlsZQ%3D%3D?line=73'>74</a> grads = tape.gradient(loss_value, model.trainable_variables)
#      <a href='vscode-notebook-cell:/c%3A/Users/Grego/Desktop/reinforcement%20learning%20pong/test.ipynb#W5sZmlsZQ%3D%3D?line=74'>75</a> print('gradient done')
#      <a href='vscode-notebook-cell:/c%3A/Users/Grego/Desktop/reinforcement%20learning%20pong/test.ipynb#W5sZmlsZQ%3D%3D?line=75'>76</a> optimizer.apply_gradients(zip(grads, model.trainable_variables))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\backprop.py:1063, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1057   output_gradients = (
#    1058       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1059           output_gradients))
#    1060   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1061                       for x in output_gradients]
# -> 1063 flat_grad = imperative_grad.imperative_grad(
#    1064     self._tape,
#    1065     flat_targets,
#    1066     flat_sources,
#    1067     output_gradients=output_gradients,
#    1068     sources_raw=flat_sources_raw,
#    1069     unconnected_gradients=unconnected_gradients)
#    1071 if not self._persistent:
#    1072   # Keep track of watched variables before setting tape to None
#    1073   self._watched_variables = self._tape.watched_variables()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\backprop.py:146, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     144     gradient_name_scope += forward_pass_name_scope + "/"
#     145   with ops.name_scope(gradient_name_scope):
# --> 146     return grad_fn(mock_op, *out_grads)
#     147 else:
#     148   return grad_fn(mock_op, *out_grads)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\math_grad.py:1737, in _MatMulGrad(op, grad)
#    1735 if not t_a and not t_b:
#    1736   grad_a = gen_math_ops.mat_mul(grad, b, transpose_b=True)
# -> 1737   grad_b = gen_math_ops.mat_mul(a, grad, transpose_a=True)
#    1738 elif not t_a and t_b:
#    1739   grad_a = gen_math_ops.mat_mul(grad, b)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\gen_math_ops.py:6719, in mat_mul(a, b, transpose_a, transpose_b, name)
#    6717   return _result
#    6718 except _core._NotOkStatusException as e:
# -> 6719   _ops.raise_from_not_ok_status(e, name)
#    6720 except _core._FallbackException:
#    6721   pass
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py:6656, in raise_from_not_ok_status(e, name)
#    6654 def raise_from_not_ok_status(e, name):
#    6655   e.message += (" name: " + str(name if name is not None else ""))
# -> 6656   raise core._status_to_exception(e) from None
#
# ResourceExhaustedError: {{function_node __wrapped__MatMul_device_/job:localhost/replica:0/task:0/device:CPU:0}} OOM when allocating tensor with shape[22528,512] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator cpu [Op:MatMul] name:
